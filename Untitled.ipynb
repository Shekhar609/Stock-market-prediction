# %%
import numpy as np
x=np.array([1,2,3,4])
print(x)
print(type(x))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
y=[1,2,3,4]
print(y)
# Out:
# [1, 2, 3, 4]

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 4.74 µs ± 265 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
import numpy as np
# %timeitnp.arange(1,9)**4
# Out:
# UsageError: Line magic function `%timeitnp.arange(1,9)**4` not found.

# %%
x=30+40
print(x)
# Out:
# 70

# %%
a=40
b=30
print(a+b)
# Out:
# 70

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
for i in range(10):
print('shekhar')
# Out:
#   Cell In[6], line 2
#     print('shekhar')
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
import matplotlib.pyplot as pit
pit.plot([2,11,15,40],[4,8,15,22],color='g')
pit.show()

# %%
pit.plot([2,11,15,40],[4,8,15,22],'gs')
pit.show()

# %%
names=['A','B','C']
values=[19,50,29]

pit.bar(names,values)
pit.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
fig = plt.figure()
ax = fig.gca(projection='3d')

x=np.arange(-10,10,0.40)
y=np.arange(-10,10,0.40)
x,y=np.meshgrid(x,y)
R=np.sqrt(x**2+y**2)
z=np.sin(R)
surf=ax.plot_surface(x,y,z, cmap=cm.spectral)
fig.colorbar(surf,shrink=0.5,aspect=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       4 import numpy as np
#       5 fig = plt.figure()
# ----> 6 ax = fig.gca(projection='3d')
#       8 x=np.arange(-10,10,0.40)
#       9 y=np.arange(-10,10,0.40)
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'
